# %%
import os
from dataset import ShapesDataset

mode = "valid" #valid or train

#データの読み取り
TRAIN_DATASET = os.path.join('dataset', mode)
dataset_train = ShapesDataset()
dataset_train.load_dataset(TRAIN_DATASET)
dataset_train.prepare()
# Out:
# dataset\valid\mask\00023_00008.png
# dataset\valid\mask\00023_00009.png
# dataset\valid\mask\00023_00011.png
# dataset\valid\mask\00049_00001.png
# dataset\valid\mask\00049_00002.png
# dataset\valid\mask\00049_00003.png
# dataset\valid\mask\00049_00004.png
# dataset\valid\mask\00049_00005.png

# %%
from mrcnn import visualize
image_ids = dataset_train.image_ids
for TRAIN_DATASET in image_ids:
    image = dataset_train.load_image(TRAIN_DATASET)
    mask, class_ids = dataset_train.load_mask(TRAIN_DATASET)
    print(dataset_train.class_names)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)
# Out:
# hoge
# {'id': '00023_00008', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00023_00008.png'), 'mask_path': WindowsPath('dataset/valid/mask/00023_00008.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
# hoge
# {'id': '00023_00009', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00023_00009.png'), 'mask_path': WindowsPath('dataset/valid/mask/00023_00009.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
# hoge
# {'id': '00023_00011', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00023_00011.png'), 'mask_path': WindowsPath('dataset/valid/mask/00023_00011.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
# hoge
# {'id': '00049_00001', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00049_00001.png'), 'mask_path': WindowsPath('dataset/valid/mask/00049_00001.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
# hoge
# {'id': '00049_00002', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00049_00002.png'), 'mask_path': WindowsPath('dataset/valid/mask/00049_00002.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
# hoge
# {'id': '00049_00003', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00049_00003.png'), 'mask_path': WindowsPath('dataset/valid/mask/00049_00003.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
# hoge
# {'id': '00049_00004', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00049_00004.png'), 'mask_path': WindowsPath('dataset/valid/mask/00049_00004.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
# hoge
# {'id': '00049_00005', 'source': 'MaskRCNN_dataset', 'path': WindowsPath('dataset/valid/image/00049_00005.png'), 'mask_path': WindowsPath('dataset/valid/mask/00049_00005.png'), 'width': 896, 'height': 896}
# ['BG', 'GNR', 'GPC', 'neutrophils', 'epithelium']
